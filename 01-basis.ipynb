# %%
import sys
print(sys.version)
print(sys.executable)
# Out:
# 3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)]
# D:\programming\python\devtool\anaconda\python.exe

# %%
# %pwd
# Out:
# 'D:\\programming\\python\\project\\jupyter\\python-data-analysis'

# %%
b = [1, 2, 3]
b?

# %%
import numpy as np
np.*load*?
#np.__loader__
#np.load
#np.loads
#np.loadtxt

# %%
tuple1 = (1, 2, 3)
tuple2 = tuple1
print(tuple1 is tuple2)
print(f'tuple1 id is {id(tuple1)}')
print(f'tuple2 id is {id(tuple2)}')
# Out:
# True
# tuple1 id is 2717758755584
# tuple2 id is 2717758755584

# %%
# str是不可变的
words = 'hello, hi.'
print(id(words))
# 返回新变量而不是在原变量上修改
words2 = words.replace('h','H')
print(words2)
print(id(words2))
# Out:
# 2717761742512
# Hello, Hi.
# 2717761698160

# %%
# 元组
tup = 1, 2, 3
print(tup)
print(type(tup))
# Out:
# (1, 2, 3)
# <class 'tuple'>

# %%
with open('./01-basis.ipynb', 'r', encoding='utf-8') as f:
    for line in f:
        print(line)
# Out:
# {
#
#  "cells": [
#
#   {
#
#    "cell_type": "code",
#
#    "execution_count": 1,
#
#    "id": "821a5841",
#
#    "metadata": {},
#
#    "outputs": [
#
#     {
#
#      "name": "stdout",
#
#      "output_type": "stream",
#
#      "text": [
#
#       "3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)]\n",
#
#       "D:\\programming\\python\\devtool\\anaconda\\python.exe\n"
#
#      ]
#
#     }
#
#    ],
#
#    "source": [
#
#     "import sys\n",
#
#     "print(sys.version)\n",
#
#     "print(sys.executable)"
#
#    ]
#
#   },
#
#   {
#
#    "cell_type": "code",
#
#    "execution_count": 1,
#
#    "id": "59ac2bd9",
#
#    "metadata": {},
#
#    "outputs": [
#
#     {
#
#      "data": {
#
#       "text/plain": [
#
#        "'D:\\\\programming\\\\python\\\\project\\\\jupyter\\\\python-data-analysis'"
#
#       ]
#
#      },
#
#      "execution_count": 1,
#
#      "metadata": {},
#
#      "output_type": "execute_result"
#
#     }
#
#    ],
#
#    "source": [
#
#     "%pwd"
# ...
